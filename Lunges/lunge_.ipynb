# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from drive.MyDrive.Fitbuddy_Susanket.csv_with_lib.lunges.Library import main

# %%
class myclass(main):

     def select_generator(self, df):
          select = ['x_0','y_0','z_0']
          for index in (11,23,25,27,29,31):
               for axis in ('x_','y_','z_'):
                    select.append(axis+str(index))
          return select,df

     def set_defaults(self):
          # path to the data
          self.path = "/content/drive/MyDrive/Fitbuddy_Susanket/csv_with_lib/lunges/"

          #default value for rep sepration
          self.rep_seprator_landmark = 'y_0'
          self.rep_seprator_sign = -1

          #probability of using a videos in a reps
          self.video_rep_probability = 0.5

          #probability of using a rep for testing
          self.rep_probability = 0.5

          #animation rep limit per video
          self.rep_anime_limit = 10

          # some other values
          self.ad = 1
          self.td = True
          self.diff = True
          self.normal = True
          #self.select_len = 50

# %%
mn = myclass()

# %%
mn.trainer(3)
# Out:
# reading the data
# torch.Size([8, 56])
# training the models
# model_id: 10001, trained_using: Lunges_Deepak-01
# 100%|██████████| 1000/1000 [00:43<00:00, 23.16it/s]
# model_id: 10002, trained_using: Lunges_Deepak-01
# 100%|██████████| 1000/1000 [00:43<00:00, 22.82it/s]
# model_id: 10003, trained_using: Lunges_Deepak-01
# 100%|██████████| 1000/1000 [00:45<00:00, 22.16it/s]
# model_id: 10004, trained_using: Lunges_Deepak-02
# 100%|██████████| 1000/1000 [00:40<00:00, 24.85it/s]
# model_id: 10005, trained_using: Lunges_Deepak-02
# 100%|██████████| 1000/1000 [00:40<00:00, 24.95it/s]
# model_id: 10006, trained_using: Lunges_Deepak-02
# 100%|██████████| 1000/1000 [00:39<00:00, 25.41it/s]
# model_id: 10007, trained_using: Lunge_Khushal-03
# 100%|██████████| 1000/1000 [00:25<00:00, 39.69it/s]
# model_id: 10008, trained_using: Lunge_Khushal-03
# 100%|██████████| 1000/1000 [00:25<00:00, 39.51it/s]
# model_id: 10009, trained_using: Lunge_Khushal-03
# 100%|██████████| 1000/1000 [00:25<00:00, 39.55it/s]
# model_id: 10010, trained_using: Lunge_Khushal-02
# 100%|██████████| 1000/1000 [00:43<00:00, 23.06it/s]
# model_id: 10011, trained_using: Lunge_Khushal-02
# 100%|██████████| 1000/1000 [00:43<00:00, 23.18it/s]
# model_id: 10012, trained_using: Lunge_Khushal-02
# 100%|██████████| 1000/1000 [00:43<00:00, 23.15it/s]
# model_id: 10013, trained_using: Lunge_Khushal-01
# 100%|██████████| 1000/1000 [00:55<00:00, 18.09it/s]
# model_id: 10014, trained_using: Lunge_Khushal-01
# 100%|██████████| 1000/1000 [00:53<00:00, 18.76it/s]
# model_id: 10015, trained_using: Lunge_Khushal-01
# 100%|██████████| 1000/1000 [00:52<00:00, 18.94it/s]

# %%
mn.generator(10003)
# Out:
# Reloaded model trained for 1000 epochs.
